# %% [markdown]
# <a href="https://colab.research.google.com/github/AlisaLeibova/ML-study/blob/main/Copy_of_HW_2_1_%D0%A4%D1%83%D0%BD%D0%BA%D1%86%D1%96%D1%97_%D1%96_%D0%BF%D0%BE%D1%85%D1%96%D0%B4%D0%BD%D1%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Домашні завдання на відпрацювання поняття функції та її похідної
#
# 1. Задана функція залежності оцінки від кількості годин, витрачених на навчання: $ f(x) = 10x - 5 $.
#   1. З допомогою Python обчисліть похідну цієї функції.
#   2. Використовуйте бібліотеку `matplotlib` для побудови графіків функції та її похідної в діапазоні значень від 0 до 10 годин. Проаналізуйте, як зміна кількості годин вивчення впливає на оцінку.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 10)
f= 10*x-5
df = 10 * np.ones_like(x)

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, f, label='f= 10*x-5', color='blue')
plt.plot(x, df, label="f'(x) = 10", color='green')
plt.xlabel('Hours Spent', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.title('Time Spent Impact on Score', fontsize=12)
plt.legend()

plt.show()

# %% [markdown]
# Зміна кількості годин (x+1) вивчення впливає на оцінку на 10 пунктів

# %% [markdown]
# 2. Використовуючи Python і `SymPy`, обчисліть похідні для функцій $ f(x) = \sin(x) $ та $ f(x) = \ln(x) $. Зобразіть ці функції та їхні похідні за допомогою `matplotlib`.

# %%
import sympy as sp
x = sp.symbols('x')
f_sin = sp.sin(x)
f_lin = sp.ln(x)
derivative_f_sin = sp.diff(f_sin, x)
derivative_f_lin = sp.diff(f_lin, x)

# %%
sp.plot(
    (f_sin, (x, 0.1, 5)),
    (derivative_f_sin, (x, 0.1, 5)),
    (f_lin, (x, 0.1, 5)),
    (derivative_f_lin, (x, 0.1, 5)),
    title="Графики функций в SymPy",
    legend=True)

# %% [markdown]
# 3. Загальні витрати компанії від обсягу виробництва задані функцією $ f(x) = x^2 - 5x + 1 $, де $ x $ — кількість вироблених одиниць. Обчисліть похідну цієї функції з допомогою SymPy та візуалізуйте значення функції і її похідної на відрізку від 0 до 100.

# %%
x = sp.symbols('x')
f = x**2+5*x+1
df = sp.diff(f,x)

# %%
sp.plot(
    (f, (x, 100, 0)),
    (df, (x, 100, 0)),
    title="Загальні витрати компанії від обсягу виробництва",
    legend=True)
